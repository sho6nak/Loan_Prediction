# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
dataset=pd.read_csv('Data/sample_data_intw.csv')
dataset.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %%
dataset.drop(['Unnamed: 0','msisdn','pcircle'],inplace=True, axis=1)

# %%
dataset.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90       pdate
# 0                 0.0  29.000000  29.000000  2016-07-20
# 1                 0.0   0.000000   0.000000  2016-08-10
# 2                 0.0   0.000000   0.000000  2016-08-19
# 3                 0.0   0.000000   0.000000  2016-06-06
# 4                 0.0   2.333333   2.333333  2016-06-22

# %%
dataset['pdate']=pd.to_datetime(dataset['pdate'])

# %%
dataset['year'] = dataset['pdate'].dt.year

# %%
dataset['month'] = dataset['pdate'].dt.month

# %%
dataset['day'] = dataset['pdate'].dt.day

# %%
dataset = dataset.drop(['year','pdate'], axis=1)

# %%
dataset
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# 1                    20.0                0.0              5787              1
# 2                     3.0                0.0              1539              1
# 3                    41.0                0.0               947              0
# 4                     4.0                0.0              2309              7
# ...                   ...                ...               ...            ...
# 209588                1.0                0.0              4048              3
# 209589                4.0                0.0               773              4
# 209590                3.0                0.0              1539              5
# 209591                2.0               38.0               773              5
# 209592               13.0                0.0              7526              2
#
#         fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0               21.0             3078.0                1539.0
# 1                0.0             5787.0                5787.0
# 2                0.0             1539.0                1539.0
# 3                0.0                0.0                   0.0
# 4                2.0            20029.0                2309.0
# ...              ...                ...                   ...
# 209588           2.0            10404.0                3178.0
# 209589           1.0             3092.0                 773.0
# 209590           8.0             9334.0                1539.0
# 209591           4.0            12154.0                 773.0
# 209592           1.0             9065.0                4532.5
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                       7.50              2            21               3078
# 1                      61.04              1             0               5787
# 2                      66.32              1             0               1539
# 3                       0.00              1             0                947
# 4                      29.00              8             2              23496
# ...                      ...            ...           ...                ...
# 209588                 91.81              3             2              10404
# 209589                161.30              6             2               4038
# 209590                 51.13             11             5              18592
# 209591                164.00              6             4              17941
# 209592                356.70              3            19              16591
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 0                     1539.0                  7.50            0.0
# 1                     5787.0                 61.04            0.0
# 2                     1539.0                 66.32            0.0
# 3                      947.0                  2.50            0.0
# 4                     2888.0                 35.00            0.0
# ...                      ...                   ...            ...
# 209588                3178.0                 91.81            0.0
# 209589                 773.0                111.80            0.0
# 209590                1539.0                 47.13            0.0
# 209591                2410.5                100.00            0.0
# 209592                7526.0                392.20            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 0                0.0              0             0            2            12
# 1                0.0              0             0            1            12
# 2                0.0              0             0            1             6
# 3                0.0              0             0            2            12
# 4                0.0              0             0            7            42
# ...              ...            ...           ...          ...           ...
# 209588           0.0              0             0            2            12
# 209589           0.0              0             0            3            18
# 209590           0.0              0             0            4            42
# 209591           0.0              1             0            2            18
# 209592           0.0              0             0            2            18
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0                   6.0                 0.0          2.0            12
# 1                  12.0                 0.0          1.0            12
# 2                   6.0                 0.0          1.0             6
# 3                   6.0                 0.0          2.0            12
# 4                   6.0                 0.0          7.0            42
# ...                 ...                 ...          ...           ...
# 209588              6.0                 0.0          2.0            12
# 209589              6.0                 0.0          3.0            18
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  month  day
# 0                     6                 0.0  29.000000  29.000000      7   20
# 1                    12                 0.0   0.000000   0.000000      8   10
# 2                     6                 0.0   0.000000   0.000000      8   19
# 3                     6                 0.0   0.000000   0.000000      6    6
# 4                     6                 0.0   2.333333   2.333333      6   22
# ...                 ...                 ...        ...        ...    ...  ...
# 209588                6                 0.0   1.000000   1.000000      6   17
# 209589                6                 0.0   1.000000   1.000000      6   12
# 209590               12                 0.0   4.000000   3.833333      7   29
# 209591               12                 0.0   0.000000  10.500000      7   25
# 209592               12                 0.0   0.000000   0.000000      7    7
#
# [209593 rows x 35 columns]

# %%
#dataset.to_csv('Data/DataPreprocessBasic.csv',index=False)

# %% [markdown]
# ## Feature Scaling

# %%
scaling_feature=[feature for feature in dataset.columns if feature not in 'label']
scaling_feature
# Out:
# ['aon',
#  'daily_decr30',
#  'daily_decr90',
#  'rental30',
#  'rental90',
#  'last_rech_date_ma',
#  'last_rech_date_da',
#  'last_rech_amt_ma',
#  'cnt_ma_rech30',
#  'fr_ma_rech30',
#  'sumamnt_ma_rech30',
#  'medianamnt_ma_rech30',
#  'medianmarechprebal30',
#  'cnt_ma_rech90',
#  'fr_ma_rech90',
#  'sumamnt_ma_rech90',
#  'medianamnt_ma_rech90',
#  'medianmarechprebal90',
#  'cnt_da_rech30',
#  'fr_da_rech30',
#  'cnt_da_rech90',
#  'fr_da_rech90',
#  'cnt_loans30',
#  'amnt_loans30',
#  'maxamnt_loans30',
#  'medianamnt_loans30',
#  'cnt_loans90',
#  'amnt_loans90',
#  'maxamnt_loans90',
#  'medianamnt_loans90',
#  'payback30',
#  'payback90',
#  'month',
#  'day']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(dataset[scaling_feature])
# Out:
# StandardScaler()

# %%
scaler.transform(dataset[scaling_feature])
# Out:
# array([[-0.10357685, -0.25229941, -0.27634619, ...,  2.39409346,
#          0.27336037,  0.6637208 ],
#        [-0.09776412,  0.73103667,  0.5533797 , ..., -0.41923266,
#          1.62209905, -0.52127058],
#        [-0.10010243, -0.43201111, -0.42903256, ..., -0.41923266,
#          1.62209905,  0.54522166],
#        ...,
#        [-0.09378769,  0.70079045,  0.53319431, ..., -0.04735622,
#          0.27336037,  1.73021304],
#        [-0.08428915,  0.77075515,  0.59455827, ...,  0.59938541,
#          0.27336037,  1.25621649],
#        [-0.08628398, -0.09674426, -0.14174607, ..., -0.41923266,
#          0.27336037, -0.87676799]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([dataset[['label']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(dataset[scaling_feature]), columns=scaling_feature)],
                    axis=1)

# %%
data.head()
# Out:
#    label       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0 -0.103577     -0.252299     -0.276346 -0.573844 -0.558583
# 1      1 -0.097764      0.731037      0.553380  0.231788  0.036020
# 2      1 -0.100102     -0.432011     -0.429033 -0.416020 -0.447674
# 3      1 -0.103986     -0.581326     -0.555125 -0.587935 -0.576036
# 4      1 -0.094660     -0.567293     -0.543274 -0.369886 -0.413227
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0          -0.069637           -0.06955         -0.221637      -0.464760
# 1          -0.069303           -0.06955          1.570178      -0.699718
# 2          -0.069619           -0.06955         -0.221637      -0.699718
# 3          -0.068914           -0.06955         -0.471344      -0.934677
# 4          -0.069600           -0.06955          0.103151       0.710030
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0     -0.069279          -0.456281             -0.132224
# 1     -0.069670          -0.189110              1.919098
# 2     -0.069670          -0.608062             -0.132224
# 3     -0.069670          -0.759843             -0.875394
# 4     -0.069633           1.215482              0.239602
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0             -0.071185      -0.599911      1.055043          -0.552756
# 1             -0.070194      -0.738926     -0.612919          -0.392058
# 2             -0.070096      -0.738926     -0.612919          -0.644049
# 3             -0.071324      -0.738926     -0.612919          -0.679166
# 4             -0.070787       0.234181     -0.454065           0.658438
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0             -0.156410             -0.228933      -0.062759     -0.069583
# 1              1.884253             -0.083923      -0.062759     -0.069583
# 2             -0.156410             -0.069622      -0.062759     -0.069583
# 3             -0.440797             -0.242476      -0.062759     -0.069583
# 4              0.491625             -0.154451      -0.062759     -0.069583
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0      -0.104375     -0.048048    -0.297116     -0.342470        -0.063284
# 1      -0.104375     -0.048048    -0.688582     -0.342470        -0.061871
# 2      -0.104375     -0.048048    -0.688582     -0.687700        -0.063284
# 3      -0.104375     -0.048048    -0.297116     -0.342470        -0.063284
# 4      -0.104375     -0.048048     1.660218      1.383682        -0.063284
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0           -0.247794    -0.073493     -0.439950        -0.334212
# 1           -0.247794    -0.077941     -0.439950         2.517690
# 2           -0.247794    -0.077941     -0.666624        -0.334212
# 3           -0.247794    -0.073493     -0.439950        -0.334212
# 4           -0.247794    -0.051250      0.693417        -0.334212
#
#    medianamnt_loans90  payback30  payback90     month       day
# 0           -0.229594    2.90470   2.394093  0.273360  0.663721
# 1           -0.229594   -0.38563  -0.419233  1.622099 -0.521271
# 2           -0.229594   -0.38563  -0.419233  1.622099  0.545222
# 3           -0.229594   -0.38563  -0.419233 -1.075378 -0.995267
# 4           -0.229594   -0.12089  -0.192873 -1.075378  0.900719

# %%
data.to_csv('Data/DataPreprocessedStdNorm.csv',index=False)
